# %%
import mtcnn
# Out:
# Using TensorFlow backend.

# %%
import cv2

# %%
import matplotlib.pyplot as plt

# %%
from mtcnn.mtcnn import MTCNN

# %%
detector= MTCNN()

# %%
image=cv2.imread('/Users/garima/GAN/swimteam_test.jpg')

# %%
detector.detect_faces(image)
# Out:
# [{'box': [2757, 1361, 229, 269],
#   'confidence': 0.9999921321868896,
#   'keypoints': {'left_eye': (2825, 1462),
#    'right_eye': (2926, 1470),
#    'nose': (2867, 1519),
#    'mouth_left': (2823, 1556),
#    'mouth_right': (2916, 1562)}},
#  {'box': [1908, 909, 189, 233],
#   'confidence': 0.9999819993972778,
#   'keypoints': {'left_eye': (1970, 994),
#    'right_eye': (2057, 999),
#    'nose': (2016, 1042),
#    'mouth_left': (1968, 1078),
#    'mouth_right': (2054, 1083)}},
#  {'box': [1274, 1189, 196, 244],
#   'confidence': 0.999956488609314,
#   'keypoints': {'left_eye': (1341, 1279),
#    'right_eye': (1431, 1283),
#    'nose': (1389, 1330),
#    'mouth_left': (1332, 1364),
#    'mouth_right': (1427, 1369)}},
#  {'box': [1692, 1063, 195, 238],
#   'confidence': 0.9999083280563354,
#   'keypoints': {'left_eye': (1745, 1164),
#    'right_eye': (1838, 1158),
#    'nose': (1795, 1203),
#    'mouth_left': (1756, 1244),
#    'mouth_right': (1840, 1241)}},
#  {'box': [879, 1313, 210, 274],
#   'confidence': 0.9998692274093628,
#   'keypoints': {'left_eye': (944, 1426),
#    'right_eye': (1039, 1428),
#    'nose': (993, 1483),
#    'mouth_left': (939, 1510),
#    'mouth_right': (1040, 1512)}},
#  {'box': [2140, 1310, 195, 252],
#   'confidence': 0.9997923970222473,
#   'keypoints': {'left_eye': (2194, 1399),
#    'right_eye': (2287, 1404),
#    'nose': (2234, 1444),
#    'mouth_left': (2190, 1493),
#    'mouth_right': (2277, 1498)}},
#  {'box': [2266, 1011, 179, 226],
#   'confidence': 0.9997819066047668,
#   'keypoints': {'left_eye': (2306, 1101),
#    'right_eye': (2390, 1103),
#    'nose': (2336, 1142),
#    'mouth_left': (2303, 1178),
#    'mouth_right': (2386, 1181)}},
#  {'box': [1642, 1579, 175, 217],
#   'confidence': 0.9993466734886169,
#   'keypoints': {'left_eye': (1685, 1664),
#    'right_eye': (1764, 1658),
#    'nose': (1724, 1713),
#    'mouth_left': (1698, 1748),
#    'mouth_right': (1766, 1743)}},
#  {'box': [1077, 710, 198, 258],
#   'confidence': 0.9992560744285583,
#   'keypoints': {'left_eye': (1134, 812),
#    'right_eye': (1223, 817),
#    'nose': (1175, 866),
#    'mouth_left': (1129, 897),
#    'mouth_right': (1219, 902)}},
#  {'box': [2649, 811, 210, 271],
#   'confidence': 0.9983421564102173,
#   'keypoints': {'left_eye': (2695, 910),
#    'right_eye': (2791, 903),
#    'nose': (2739, 967),
#    'mouth_left': (2706, 1014),
#    'mouth_right': (2793, 1007)}},
#  {'box': [2994, 1261, 208, 272],
#   'confidence': 0.9981523156166077,
#   'keypoints': {'left_eye': (3048, 1366),
#    'right_eye': (3141, 1372),
#    'nose': (3086, 1435),
#    'mouth_left': (3046, 1465),
#    'mouth_right': (3131, 1469)}},
#  {'box': [519, 1178, 41, 56],
#   'confidence': 0.9677033424377441,
#   'keypoints': {'left_eye': (526, 1202),
#    'right_eye': (544, 1201),
#    'nose': (529, 1213),
#    'mouth_left': (525, 1226),
#    'mouth_right': (540, 1225)}}]

# %%
cap =cv2.VideoCapture(0)

# %%
import time
timeout = time.time() + 60*1

# %%
while time.time()<timeout:
    #capture frame by frame
    _ , frame=cap.read()
    #use MTCNN to detect faces
    faces=detector.detect_faces(frame)
   
    for person in faces:
            bounding_box = person['box']
            keypoints = person['keypoints']
            
            #draw box around the face
            cv2.rectangle(frame, (bounding_box[0], bounding_box[1]), (bounding_box[0]+bounding_box[2], bounding_box[1]+bounding_box[3]),(0,155,255),2)
            
            # draw circles to show keypoints :eyes, nose, mouth
            cv2.circle(frame,(keypoints['left_eye']), 2,(0,155,255),2)
            cv2.circle(frame,(keypoints['right_eye']), 2,(0,155,255),2)
            cv2.circle(frame,(keypoints['nose']), 2,(0,155,255),2)
            cv2.circle(frame,(keypoints['mouth_left']), 2,(0,155,255),2)
            cv2.circle(frame,(keypoints['mouth_right']), 2,(0,155,255),2)
            #cv2.imwrite("video_test.png", image)
    
            #display resulting frame
            plt.imshow(frame)

# %%
cap.release()
cv2.destroyAllWindows()
